# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(32, activation='relu', input_dim=100))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Generate dummy data
import numpy as np
data = np.random.random((1000, 100))
labels = np.random.randint(10, size=(1000, 1))

# Convert labels to categorical one-hot encoding
one_hot_labels = keras.utils.to_categorical(labels, num_classes=10)

# Train the model, iterating on the data in batches of 32 samples
history = model.fit(data, one_hot_labels, epochs=10, batch_size=32)

model.summary()
# Out:
# Epoch 1/10
# 1000/1000 [==============================] - 0s 340us/step - loss: 2.3641 - acc: 0.0850
# Epoch 2/10
# 1000/1000 [==============================] - 0s 63us/step - loss: 2.3270 - acc: 0.0930
# Epoch 3/10
# 1000/1000 [==============================] - 0s 68us/step - loss: 2.3099 - acc: 0.1100
# Epoch 4/10
# 1000/1000 [==============================] - 0s 73us/step - loss: 2.2983 - acc: 0.1160
# Epoch 5/10
# 1000/1000 [==============================] - 0s 67us/step - loss: 2.2916 - acc: 0.1260
# Epoch 6/10
# 1000/1000 [==============================] - 0s 68us/step - loss: 2.2830 - acc: 0.1440
# Epoch 7/10
# 1000/1000 [==============================] - 0s 85us/step - loss: 2.2767 - acc: 0.1500
# Epoch 8/10
# 1000/1000 [==============================] - 0s 67us/step - loss: 2.2703 - acc: 0.1600
# Epoch 9/10
# 1000/1000 [==============================] - 0s 89us/step - loss: 2.2621 - acc: 0.1590
# Epoch 10/10
# 1000/1000 [==============================] - 0s 71us/step - loss: 2.2530 - acc: 0.1630
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                3232
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 3,562
# Trainable params: 3,562
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
plt.plot(data)
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt

# = model.fit(data, labels, validation_split=0.25, epochs=50, batch_size=16, verbose=1)

# Plot training & validation accuracy values
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-a70a03bfdc32> in <module>
#       5 # Plot training & validation accuracy values
#       6 plt.plot(history.history['acc'])
# ----> 7 plt.plot(history.history['val_acc'])
#       8 plt.title('Model accuracy')
#       9 plt.ylabel('Accuracy')
#
# KeyError: 'val_acc'
